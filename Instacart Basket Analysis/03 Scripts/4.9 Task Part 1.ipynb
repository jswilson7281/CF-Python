# %% [markdown]
# # Part 1

# %% [markdown]
# 1)Download the customer data set and add it to your “Original Data” folder.
#
# 2)Create a new notebook in your “Scripts” folder for part 1 of this task.
#
# 3)Import your analysis libraries, as well as your new customer data set as a dataframe.

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Create path
path=path = r"C:\Users\justi\02-24 Instacart Basket Analysis"

# %%
# Import data set as dataframe
df=pd.read_csv(r"C:\Users\justi\02-24 Instacart Basket Analysis\02 Data\Original Data\customers data set\customers.csv")

# %%
# Check
df.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
# Check
df.shape
# Out:
# (206209, 10)

# %% [markdown]
# 4)Wrangle the data so that it follows consistent logic; for example, rename columns with illogical names and drop columns that don’t add anything to your analysis.

# %%
# Rename Columns
df=df.rename(columns={'User_ID':'user_id','Surnam': 'Last Name', 'STATE':'State', 'date_joined':'Date_Joined', 'n_dependants': 'Dependants', 'fam_status': 'Family_Status', 'income': 'Income'})

# %%
# Check new column Names
df.head()
# Out:
#    user_id First Name Last Name  Gender       State  Age Date_Joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    Dependants Family_Status  Income
# 0           3       married  165665
# 1           0        single   59285
# 2           2       married   99568
# 3           0        single   42049
# 4           1       married   40374

# %% [markdown]
# 5)Complete the fundamental data quality and consistency checks you’ve learned throughout this Achievement; for example, check for and address missing values and duplicates, and convert any mixed-type data.

# %%
# Check for missing values and duplicates
missing_values=df.isnull().sum()

# %%
print(missing_values)
# Out:
# user_id              0
# First Name       11259
# Last Name            0
# Gender               0
# State                0
# Age                  0
# Date_Joined          0
# Dependants           0
# Family_Status        0
# Income               0
# dtype: int64

# %%
df_nan = df[df['First Name'].isnull()==True]

# %%
df_nan
# Out:
#         user_id First Name Last Name  Gender         State  Age Date_Joined  \
# 53        76659        NaN   Gilbert    Male      Colorado   26    1/1/2017
# 73        13738        NaN     Frost  Female     Louisiana   39    1/1/2017
# 82        89996        NaN    Dawson  Female        Oregon   52    1/1/2017
# 99        96166        NaN   Oconnor    Male      Oklahoma   51    1/1/2017
# 105       29778        NaN    Dawson  Female          Utah   63    1/1/2017
# ...         ...        ...       ...     ...           ...  ...         ...
# 206038   121317        NaN    Melton    Male  Pennsylvania   28   3/31/2020
# 206044   200799        NaN  Copeland  Female        Hawaii   52    4/1/2020
# 206090   167394        NaN     Frost  Female        Hawaii   61    4/1/2020
# 206162   187532        NaN     Floyd  Female    California   39    4/1/2020
# 206171   116898        NaN   Delgado  Female      Colorado   23    4/1/2020
#
#         Dependants Family_Status  Income
# ...

# %% [markdown]
# Since it's just the first names of some user's I'll keep them in the data frame
# because it's still useful data.

# %%
#check for duplicates
df_dups=df[df.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [user_id, First Name, Last Name, Gender, State, Age, Date_Joined, Dependants, Family_Status, Income]
# Index: []

# %% [markdown]
# No duplicates detected in data frame

# %%
# Check for mixed-type data

for col in df.columns.tolist():
  weird = (df[[col]].map(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df[weird]) > 0:
    print (col)
# Out:
# First Name

# %%
# Fix Duplicates
df['First Name']=df['First Name'].astype('str')

# %%
# Test again 
for col in df.columns.tolist():
  weird = (df[[col]].map(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df[weird]) > 0:
    print (col)

# %% [markdown]
# Duplicates were all first names so just fixed as string becuase it is common for some people to share a first name.

# %% [markdown]
# 6)Combine your customer data with the rest of your prepared Instacart data. (Hint: Make sure the key columns are the same data type!)

# %%
# Merge df with rest of instacart data frame

# %%
# Import the instacart data frame
df_instacart=pd.read_pickle(r"C:\Users\justi\02-24 Instacart Basket Analysis\02 Data\Prepared Data\Task 4.8 Grouping Data And Aggregating Variables.pkl")

# %%
#check
df_instacart.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  hour_of_order  \
# 0   3139998  3139998            28                   6             11
# 1   1977647  1977647            30                   6             17
# 2    389851   389851             2                   0             21
# 3   1813452  1813452             3                   4             17
# 4   1701441  1701441            16                   1              7
#
#    days_since_prior_order  add_to_cart_order  reordered _merge  max_order  \
# ...

# %%
df_merged=df_instacart.merge(df,on='user_id', indicator='_merge2')

# %%
df_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'Task 4.9'))
